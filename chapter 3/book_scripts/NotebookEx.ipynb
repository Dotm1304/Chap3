# %% [markdown]
# ## Profiles and Configuration
# Trong một số trường hợp, thông tin bạn nhận được từ **%prun** (hoặc một phương thức hồ sơ dựa trên **cProfile** khác) có thể không nói lên toàn bộ câu chuyện về thời gian thực hiện của hàm hoặc có thể phức tạp đến mức khó diễn giải kết quả, được tổng hợp theo tên hàm. Đối với trường hợp này, có một thư viện nhỏ gọi là **line_profiler** (có thể lấy được qua PyPI hoặc một trong các công cụ quản lý gói). Nó chứa một tiện ích mở rộng IPython cho phép một hàm ma thuật mới **%lprun** tính toán cấu hình từng dòng của một hoặc nhiều hàm. Bạn có thể bật tiện ích mở rộng này bằng cách sửa đổi cấu hình IPython của mình (xem tài liệu IPython hoặc phần về cấu hình ở phần sau của chương này) để bao gồm dòng sau:
#
#     # A list of dotted module names of IPython extensions to load.
#     c.TerminalIPythonApp.extensions = ['line_profiler']

# %% [markdown]
# **line_profiler** có thể được sử dụng theo chương trình (xem tài liệu đầy đủ), nhưng nó có lẽ mạnh nhất khi được sử dụng tương tác trong IPython. Giả sử bạn có một mô-đun **prof_mod** với đoạn mã sau đang thực hiện một số thao tác với mảng NumPy:

# %%
from IPython.display import Image
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_3.4.4.01.jpg', width=500,height=500)

# %% [markdown]
# Nếu chúng ta muốn hiểu hiệu suất của hàm **add_and_sum**, thì **%prun** cung cấp cho chúng ta thông tin sau:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_3.4.4.02.jpg', width=500,height=500)

# %% [markdown]
# Điều này không đặc biệt giác ngộ. Với phần mở rộng **line_profiler** IPython được kích hoạt, một lệnh mới **%lprun** sẽ khả dụng. Sự khác biệt duy nhất trong cách sử dụng là chúng ta phải hướng dẫn **%lprun** chức năng hoặc các chức năng mà chúng ta muốn cấu hình. Cú pháp chung là:
#
#     %lprun -f func1 -f func2 **statement_to_profile**

# %% [markdown]
# Trong trường hợp này, chúng tôi muốn cấu hình **add_and_sum**, vì vậy chúng tôi chạy:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_3.4.4.03.jpg', width=500,height=500)

# %% [markdown]
# Bạn có thể đồng ý rằng điều này dễ giải thích hơn nhiều. Trong trường hợp này, chúng tôi đã mô tả chính chức năng mà chúng tôi đã sử dụng trong câu lệnh. Nhìn vào mã mô-đun ở trên, chúng ta có thể gọi **call_function** và **profile** cũng như **add_and_sum**, do đó có được bức tranh đầy đủ về hiệu suất của mã:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_3.4.4.04.jpg', width=500,height=500)

# %% [markdown]
# Theo nguyên tắc chung, tôi có xu hướng thích **%prun** (**cProfile**) hơn cho hồ sơ “vĩ mô” và **%lprun** (**line_profiler**) cho hồ sơ “vi mô”. Thật đáng để hiểu rõ về cả hai công cụ.

# %% [markdown]
# # IPython HTML Notebook
# Bắt đầu từ năm 2011, nhóm IPython, do Brian Granger đứng đầu, đã xây dựng một định dạng tài liệu tính toán tương tác dựa trên công nghệ web thường được gọi là IPython Notebook. Nó đã phát triển thành một công cụ tuyệt vời cho điện toán tương tác và là phương tiện lý tưởng cho nghiên cứu và giảng dạy có thể tái tạo. Tôi đã sử dụng nó khi viết hầu hết các ví dụ trong cuốn sách; tôi cũng khuyến khích bạn tận dụng nó.
#
# Nó có định dạng tài liệu là JSON-based (một text-based) **.ipynb** cho phép dễ dàng chia sẻ mã, đầu ra và số liệu. Gần đây trong các hội nghị Python, một cách tiếp cận phổ biến để trình diễn là sử dụng sổ ghi chép và đăng các tệp .ipynb trực tuyến sau đó để mọi người cùng dùng.
# Ứng dụng Notebook chạy dưới dạng quy trình máy chủ nhẹ trên dòng lệnh. Nó có thể được bắt đầu bằng cách chạy:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_01.jpg', width=700,height=700)

# %% [markdown]
# Trên hầu hết các nền tảng, trình duyệt web chính của bạn sẽ tự động mở tới bảng điều khiển của Notebook. Trong một số trường hợp, bạn có thể phải điều hướng đến URL được liệt kê. Từ đó, bạn có thể tạo Notebook mới và bắt đầu khám phá.
#
# Vì bạn sử dụng Notebook bên trong trình duyệt web nên quy trình máy chủ có thể chạy ở mọi nơi.
# Bạn thậm chí có thể kết nối an toàn với Notebook chạy trên các nhà cung cấp dịch vụ đám mây như Amazon EC2. Khi viết bài này, một dự án mới NotebookCloud (*http://notebookcloud.appspot.com*) giúp dễ dàng khởi chạy Notebook trên EC2.

# %% [markdown]
# # Tips for Productive Code Development Using IPython
# Viết mã theo cách giúp dễ dàng phát triển, gỡ lỗi và cuối cùng sử dụng tương tác có thể là một sự thay đổi mô hình đối với nhiều người dùng. Có những chi tiết thủ tục như tải lại mã có thể yêu cầu một số điều chỉnh cũng như lo ngại về kiểu mã hóa.
#
# Do đó, hầu hết phần này là một nghệ thuật hơn là một khoa học và sẽ yêu cầu một số thử nghiệm từ phía bạn để xác định cách viết mã Python hiệu quả và hiệu quả cho bạn. Cuối cùng, bạn muốn cấu trúc mã của mình theo cách giúp bạn dễ dàng sử dụng lặp đi lặp lại và có thể khám phá kết quả của việc chạy một chương trình hoặc chức năng dễ dàng nhất có thể. Tôi đã tìm thấy phần mềm được thiết kế với

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_02.jpg', width=700,height=700)

# %% [markdown]
# *Figure 3-4. IPython Notebook*

# %% [markdown]
# Lưu ý rằng IPython sẽ dễ làm việc hơn so với mã dự định chỉ chạy dưới dạng ứng dụng dòng lệnh độc lập. Điều này trở nên đặc biệt quan trọng khi có sự cố xảy ra và bạn phải chẩn đoán lỗi trong mã mà bạn hoặc người khác có thể đã viết trước đó hàng tháng hoặc hàng năm.

# %% [markdown]
# ## Reloading Module Dependencies
# Trong Python, khi bạn **import some_lib**, mã trong **some_lib** được thực thi và tất cả các biến, hàm và nhập được xác định bên trong được lưu trữ trong không gian tên mô-đun **some_lib** mới được tạo. Lần tới khi bạn nhập **import some_lib**, bạn sẽ nhận được tham chiếu đến không gian tên mô-đun hiện có. Khó khăn tiềm ẩn trong việc phát triển mã tương tác trong IPython xuất hiện khi bạn nói, **%run** một tập lệnh phụ thuộc vào một số mô-đun khác mà bạn có thể đã thực hiện các thay đổi. Giả sử tôi có đoạn mã sau trong **test_script.py**:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_03.jpg', width=500,height=500)

# %% [markdown]
# Nếu bạn thực thi **%run test_script.py** sau đó sửa đổi **some_lib.py**, thì lần tới khi bạn thực thi **%run test_script.py**, bạn vẫn sẽ nhận được *phiên bản cũ* của **some_lib** do hệ thống mô-đun “tải một lần” của Python. Hành vi này khác với một số môi trường phân tích dữ liệu khác, chẳng hạn như MATLAB, tự động truyền các thay đổi mã. Để giải quyết vấn đề này, bạn có một vài lựa chọn. Cách đầu tiên là sử dụng chức năng **reload** tích hợp sẵn của Python, thay đổi **test_script.py** thành như sau:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_04.jpg', width=500,height=500)

# %% [markdown]
# Điều này đảm bảo rằng bạn sẽ nhận được một bản sao mới của **some_lib** mỗi khi bạn chạy **test_script.py**. Rõ ràng, nếu các phụ thuộc đi sâu hơn, có thể hơi phức tạp khi chèn các tập quán tải lại ở mọi nơi. Đối với vấn đề này, IPython có chức năng **dreload** đặc biệt (*không* phải chức năng ma thuật) để tải lại mô-đun "sâu" (đệ quy). Nếu tôi chạy **import some_lib** rồi nhập **dreload(some_lib)**, nó sẽ cố tải lại **some_lib** cũng như tất cả các phần phụ thuộc của nó. Thật không may, điều này sẽ không hoạt động trong mọi trường hợp, nhưng khi nó hoạt động, nó sẽ phải khởi động lại IPython.

# %% [markdown]
# ## Code Design Tips
# Không có công thức đơn giản nào cho việc này, nhưng đây là một số nguyên tắc cấp cao mà tôi thấy hiệu quả trong công việc của mình.
# 1. Vì một mô-đun hoặc gói có thể được nhập ở nhiều vị trí khác nhau trong một chương trình cụ thể, nên Python sẽ lưu mã của mô-đun vào bộ đệm trong lần nhập đầu tiên thay vì thực thi mã trong mô-đun mỗi lần. Mặt khác, tính mô đun và tổ chức mã tốt có khả năng gây ra sự kém hiệu quả trong một ứng dụng.

# %% [markdown]
# ### Keep relevant objects and data alive
# Không có gì lạ khi thấy một chương trình được viết cho dòng lệnh có cấu trúc giống như ví dụ sau:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_05.jpg', width=1000,height=1000)

# %% [markdown]
# Bạn có thấy điều gì có thể sai với chương trình này nếu chúng ta chạy nó trong IPython không?
# Sau khi hoàn thành, không có kết quả hoặc đối tượng nào được xác định trong hàm chính sẽ không thể truy cập được trong trình bao IPython. Cách tốt hơn là để bất kỳ mã nào trong **main** được thực thi trực tiếp trong không gian tên chung của mô-đun (hoặc trong khối **if \_\_name\_\_ == '\_\_main\_\_':block**, nếu bạn muốn mô-đun cũng có thể nhập được). Bằng cách đó, khi bạn **%run** mã, bạn sẽ có thể xem xét tất cả các biến được xác định trong **main**. Nó ít có ý nghĩa hơn trong ví dụ đơn giản này, nhưng trong cuốn sách này, chúng ta sẽ xem xét một số vấn đề phân tích dữ liệu phức tạp liên quan đến các tập dữ liệu lớn mà bạn muốn có thể xử lý trong IPython.

# %% [markdown]
# ### Flat is better than nested
# Mã được lồng sâu khiến tôi nghĩ về nhiều lớp của một củ hành. Khi kiểm tra hoặc gỡ lỗi một chức năng, bạn phải bóc bao nhiêu lớp của củ hành để đạt được mã quan tâm? Ý tưởng “phẳng tốt hơn lồng” là một phần của Zen of Python và nó cũng áp dụng chung cho việc phát triển mã để sử dụng tương tác. Làm cho các chức năng và lớp được tách riêng và theo mô-đun càng tốt sẽ giúp chúng dễ kiểm tra hơn (nếu bạn đang viết bài kiểm tra đơn vị), gỡ lỗi và sử dụng một cách tương tác.

# %% [markdown]
# ### Overcome a fear of longer files
# Nếu bạn có nền tảng Java (hoặc ngôn ngữ khác như vậy), bạn có thể được yêu cầu giữ các tệp ngắn gọn. Trong nhiều ngôn ngữ, đây là lời khuyên đúng đắn; độ dài thường là “mùi mã” không tốt, cho thấy có thể cần phải tái cấu trúc hoặc tổ chức lại. Tuy nhiên, trong khi phát triển mã bằng IPython, làm việc với 10 tệp nhỏ nhưng được kết nối với nhau (dưới 100 dòng mỗi tệp) có thể khiến bạn đau đầu hơn nói chung so với một tệp lớn hoặc hai hoặc ba tệp dài hơn. Ít tệp hơn có nghĩa là ít mô-đun hơn để tải lại và cũng ít phải nhảy giữa các tệp hơn trong khi chỉnh sửa. Tôi đã tìm thấy việc duy trì các mô-đun lớn hơn, mỗi mô-đun có độ gắn kết bên trong cao, sẽ hữu ích và phong cách Pythonic hơn nhiều. Sau khi lặp đi lặp lại hướng tới một giải pháp, đôi khi sẽ hợp lý khi cấu trúc lại các tệp lớn hơn thành các tệp nhỏ hơn.
#
# Rõ ràng là tôi không ủng hộ việc đưa lập luận này đi quá xa, nghĩa là đặt tất cả mã của bạn vào một tệp khổng lồ duy nhất. Việc tìm kiếm một cấu trúc gói và mô-đun hợp lý và trực quan cho một cơ sở mã lớn thường mất nhiều công sức, nhưng điều đặc biệt quan trọng là phải làm việc đúng theo nhóm. Mỗi mô-đun phải được gắn kết bên trong và phải rõ ràng nhất có thể ở đâu để tìm các chức năng và lớp chịu trách nhiệm cho từng lĩnh vực chức năng.

# %% [markdown]
# # Advanced IPython Features

# %% [markdown]
# ## Making Your Own Classes IPython-friendly
# IPython cố gắng hết sức để hiển thị biểu diễn chuỗi thân thiện với bảng điều khiển của bất kỳ đối tượng nào mà bạn kiểm tra. Đối với nhiều đối tượng, như ký tự, danh sách và bộ dữ liệu, mô-đun **pprint** tích hợp sẵn được sử dụng để thực hiện định dạng đẹp. Tuy nhiên, trong các lớp do người dùng định nghĩa, bạn phải tự tạo đầu ra chuỗi mong muốn. Giả sử chúng ta có lớp đơn giản sau:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_06.jpg', width=500,height=500)

# %% [markdown]
# Nếu bạn viết điều này, bạn sẽ thất vọng khi phát hiện ra rằng đầu ra mặc định cho lớp học của bạn không được đẹp cho lắm:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_07.jpg', width=500,height=500)

# %% [markdown]
# IPython lấy chuỗi được trả về bởi phương thức ma thuật **\_\_repr\_\_** (bằng cách thực hiện **output = repr(obj)**) và in chuỗi đó ra bàn điều khiển. Do đó, chúng ta có thể thêm một phương thức **\_\_repr\_\_** đơn giản vào lớp trên để có được kết quả hữu ích hơn:

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_08.jpg', width=500,height=500)

# %% [markdown]
# ## Profiles and Configuration
# Hầu hết các khía cạnh về giao diện (màu sắc, dấu nhắc, khoảng cách giữa các dòng, v.v.) và hành vi của lớp vỏ IPython đều có thể định cấu hình thông qua một hệ thống cấu hình mở rộng.
# Dưới đây là một số điều bạn có thể thực hiện thông qua cấu hình:
# - Thay đổi bảng màu
# - Thay đổi giao diện của lời nhắc đầu vào và đầu ra hoặc xóa dòng trống sau
#     Ra và trước lời nhắc Tiếp theo
# - Thay đổi giao diện của lời nhắc đầu vào và đầu ra
# - Thực thi một danh sách tùy ý các câu lệnh Python. Đây có thể là những lần nhập mà bạn sử dụng mọi lúc hoặc bất kỳ thứ gì khác mà bạn muốn xảy ra mỗi khi bạn khởi chạy IPython
# - Kích hoạt tiện ích mở rộng IPython, như phép thuật **%lprun** trong **line_profiler**
# - Xác định phép thuật hoặc bí danh hệ thống của riêng bạn

# %% [markdown]
# Tất cả các tùy chọn cấu hình này được chỉ định trong một tệp **ipython_config.py** đặc biệt sẽ được tìm thấy trong thư mục **~/.config/ipython/** trên các hệ thống **UNIX-like** và thư mục **%HOME %/.ipython/** trên Windows. Thư mục chính của bạn ở đâu phụ thuộc vào hệ thống của bạn. Cấu hình được thực hiện dựa trên một cấu hình cụ thể. Khi bạn khởi động IPython bình thường, theo mặc định, bạn tải lên cấu hình mặc định, được lưu trữ trong thư mục **pro file_default**. Do đó, trên hệ điều hành Linux của tôi, đường dẫn đầy đủ đến tệp cấu hình IPython mặc định của tôi là:
#
#     /home/wesm/.config/ipython/profile_default/ipython_config.py
#
# Tôi sẽ cung cấp cho bạn những chi tiết đẫm máu về những gì có trong tệp này. May mắn thay, nó có các nhận xét mô tả từng tùy chọn cấu hình dùng để làm gì, vì vậy tôi sẽ để nó cho người đọc mày mò và tùy chỉnh. Một tính năng hữu ích bổ sung là có thể có ***multiple pro-files***. Giả sử bạn muốn có một cấu hình IPython thay thế phù hợp với một ứng dụng hoặc dự án cụ thể. Tạo một hồ sơ mới đơn giản là gõ một cái gì đó như:
#
#     ipython profile create secret_project
#
# Khi bạn đã hoàn thành việc này, hãy chỉnh sửa các tệp cấu hình trong thư mục **pro file_secret_project** mới được tạo, sau đó khởi chạy IPython như vậy

# %%
Image(filename='C:/Users/ADMIN/book_scripts/IPythonNotebook_09.jpg', width=700,height=700)

# %% [markdown]
# Như mọi khi, tài liệu IPython trực tuyến là một tài nguyên tuyệt vời để biết thêm về hồ sơ và cấu hình.

# %% [markdown]
# # Credits
# Các phần mục của chương này được lấy từ tài liệu do Nhóm phát triển IPython tập hợp. Tôi cảm ơn ơn họ rất nhiều vì họ đã xây dựng nên bộ công cụ tuyệt vời này.
